# %%
import os
import pypsa 
import matplotlib.pyplot as plt
plt.style.use("bmh")
import pandas as pd
import numpy as np
# %matplotlib inline
import seaborn as sns  ###
import cartopy.crs as ccrs
sns.set(style='darkgrid') ### seaborn gives a nice design

# %%
# %cd /mnt/d/Diss/exotic-energy-storage/pypsa-eur/scripts
# Out:
# /mnt/d/Diss/exotic-energy-storage/pypsa-eur/scripts

# %%
from _helpers import *
from make_summary import assign_carriers
from plot_summary import plot_costs

# %% [markdown]
# ## Upload network

# %%
# %cd /mnt/d/Diss/pypsa-eur-old/networks
n = pypsa.Network("elec_s_5_ec_lcopt_Co2L-24H.nc")
# Out:
# /mnt/d/Diss/pypsa-eur-old/networks
# /home/eliza/miniconda3/envs/pypsa-eur/lib/python3.8/site-packages/pypsa/io.py:771: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#   pnl[attr] = pnl[attr].reindex(columns=(pnl[attr].columns | columns))
# INFO:pypsa.io:Imported network elec_s_5_ec_lcopt_Co2L-24H.nc has buses, carriers, generators, global_constraints, lines, links, loads, stores

# %%
n.plot()
# Out:
# /home/eliza/miniconda3/envs/pypsa-eur/lib/python3.8/site-packages/pypsa/plot.py:159: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = plt.gca(projection=projection)
# (<matplotlib.collections.PatchCollection at 0x7f263f2e67f0>,
#  <matplotlib.collections.LineCollection at 0x7f263f2e28b0>,
#  <matplotlib.collections.LineCollection at 0x7f263f2bc760>)

# %%
pd.set_option('display.max_columns', None)
n.generators
# Out:
#                      p_nom_max        weight        p_nom   capital_cost  \
# name
# DE0 0 CCGT                 inf      0.000000  3372.000000       0.000000
# DE0 0 OCGT                 inf      0.000000     0.000000   47234.561404
# DE0 0 coal                 inf      0.000000   842.800000       0.000000
# DE0 0 onwind      1.084369e+05  15107.091265     0.000000  109295.569252
# DE0 0 solar       6.897636e+04   8397.640459     0.000000   55064.071419
# DE0 1 CCGT                 inf      0.000000  8338.000000       0.000000
# DE0 1 OCGT                 inf      0.000000     0.000000   47234.561404
# DE0 1 coal                 inf      0.000000  8820.942468       0.000000
# DE0 1 onwind      5.366593e+04  14113.986604     0.000000  109295.569252
# DE0 1 solar       4.821319e+04   5487.448467     0.000000   55064.071419
# DE0 2 CCGT                 inf      0.000000  2285.810000       0.000000
# DE0 2 OCGT                 inf      0.000000     0.000000   47234.561404
# DE0 2 coal                 inf      0.000000  1291.000000       0.000000
# DE0 2 offwind-ac  1.380333e+04   7121.460730     0.000000  204993.450164
# DE0 2 offwind-dc  2.797082e+03   1601.090855     0.000000  221572.344712
# DE0 2 onwind      1.131762e+05  27905.101999     0.000000  109295.569252
# DE0 2 solar       9.229174e+04  10660.116604     0.000000   55064.071419
# DE0 3 CCGT                 inf      0.000000  2704.800000       0.000000
# DE0 3 OCGT                 inf      0.000000     0.000000   47234.561404
# DE0 3 coal                 inf      0.000000  8848.300000       0.000000
# DE0 3 onwind      7.079521e+04  11641.680421     0.000000  109295.569252
# DE0 3 solar       5.817542e+04   6947.387962     0.000000   55064.071419
# DE0 4 CCGT                 inf      0.000000  1420.300000       0.000000
# DE0 4 OCGT                 inf      0.000000     0.000000   47234.561404
# DE0 4 coal                 inf      0.000000  8266.337328       0.000000
# DE0 4 offwind-ac  8.706264e+03   4218.576189     0.000000  202036.467632
# DE0 4 offwind-dc  6.431825e+04  39796.881132     0.000000  247531.003218
# DE0 4 onwind      1.026380e+05  30864.596282     0.000000  109295.569252
# DE0 4 solar       9.155205e+04  10628.506842     0.000000   55064.071419
#
#                     bus  marginal_cost  p_nom_extendable     carrier  \
# name
# DE0 0 CCGT        DE0 0      47.200000             False        CCGT
# DE0 0 OCGT        DE0 0      58.384615              True        OCGT
# DE0 0 coal        DE0 0      24.103448             False        coal
# DE0 0 onwind      DE0 0       0.015000              True      onwind
# DE0 0 solar       DE0 0       0.010000              True       solar
# DE0 1 CCGT        DE0 1      47.200000             False        CCGT
# DE0 1 OCGT        DE0 1      58.384615              True        OCGT
# DE0 1 coal        DE0 1      24.103448             False        coal
# DE0 1 onwind      DE0 1       0.015000              True      onwind
# DE0 1 solar       DE0 1       0.010000              True       solar
# DE0 2 CCGT        DE0 2      47.200000             False        CCGT
# DE0 2 OCGT        DE0 2      58.384615              True        OCGT
# DE0 2 coal        DE0 2      24.103448             False        coal
# DE0 2 offwind-ac  DE0 2       0.015000              True  offwind-ac
# DE0 2 offwind-dc  DE0 2       0.015000              True  offwind-dc
# DE0 2 onwind      DE0 2       0.015000              True      onwind
# DE0 2 solar       DE0 2       0.010000              True       solar
# DE0 3 CCGT        DE0 3      47.200000             False        CCGT
# DE0 3 OCGT        DE0 3      58.384615              True        OCGT
# DE0 3 coal        DE0 3      24.103448             False        coal
# DE0 3 onwind      DE0 3       0.015000              True      onwind
# DE0 3 solar       DE0 3       0.010000              True       solar
# DE0 4 CCGT        DE0 4      47.200000             False        CCGT
# DE0 4 OCGT        DE0 4      58.384615              True        OCGT
# DE0 4 coal        DE0 4      24.103448             False        coal
# DE0 4 offwind-ac  DE0 4       0.015000              True  offwind-ac
# DE0 4 offwind-dc  DE0 4       0.015000              True  offwind-dc
# DE0 4 onwind      DE0 4       0.015000              True      onwind
# DE0 4 solar       DE0 4       0.010000              True       solar
#
#                   efficiency control  ...  start_up_cost shut_down_cost  \
# name                                  ...
# DE0 0 CCGT             0.500   Slack  ...            0.0            0.0
# DE0 0 OCGT             0.390          ...            0.0            0.0
# DE0 0 coal             0.464          ...            0.0            0.0
# DE0 0 onwind           1.000          ...            0.0            0.0
# DE0 0 solar            1.000          ...            0.0            0.0
# DE0 1 CCGT             0.500          ...            0.0            0.0
# DE0 1 OCGT             0.390          ...            0.0            0.0
# DE0 1 coal             0.464          ...            0.0            0.0
# DE0 1 onwind           1.000          ...            0.0            0.0
# DE0 1 solar            1.000          ...            0.0            0.0
# DE0 2 CCGT             0.500          ...            0.0            0.0
# DE0 2 OCGT             0.390          ...            0.0            0.0
# DE0 2 coal             0.464          ...            0.0            0.0
# DE0 2 offwind-ac       1.000          ...            0.0            0.0
# DE0 2 offwind-dc       1.000          ...            0.0            0.0
# DE0 2 onwind           1.000          ...            0.0            0.0
# DE0 2 solar            1.000          ...            0.0            0.0
# DE0 3 CCGT             0.500          ...            0.0            0.0
# DE0 3 OCGT             0.390          ...            0.0            0.0
# DE0 3 coal             0.464          ...            0.0            0.0
# DE0 3 onwind           1.000          ...            0.0            0.0
# DE0 3 solar            1.000          ...            0.0            0.0
# DE0 4 CCGT             0.500          ...            0.0            0.0
# DE0 4 OCGT             0.390          ...            0.0            0.0
# DE0 4 coal             0.464          ...            0.0            0.0
# DE0 4 offwind-ac       1.000          ...            0.0            0.0
# DE0 4 offwind-dc       1.000          ...            0.0            0.0
# DE0 4 onwind           1.000          ...            0.0            0.0
# DE0 4 solar            1.000          ...            0.0            0.0
#
#                   min_up_time  min_down_time  up_time_before  \
# name
# DE0 0 CCGT                  0              0               1
# DE0 0 OCGT                  0              0               1
# DE0 0 coal                  0              0               1
# DE0 0 onwind                0              0               1
# DE0 0 solar                 0              0               1
# DE0 1 CCGT                  0              0               1
# DE0 1 OCGT                  0              0               1
# DE0 1 coal                  0              0               1
# DE0 1 onwind                0              0               1
# DE0 1 solar                 0              0               1
# DE0 2 CCGT                  0              0               1
# DE0 2 OCGT                  0              0               1
# DE0 2 coal                  0              0               1
# DE0 2 offwind-ac            0              0               1
# DE0 2 offwind-dc            0              0               1
# DE0 2 onwind                0              0               1
# DE0 2 solar                 0              0               1
# DE0 3 CCGT                  0              0               1
# DE0 3 OCGT                  0              0               1
# DE0 3 coal                  0              0               1
# DE0 3 onwind                0              0               1
# DE0 3 solar                 0              0               1
# DE0 4 CCGT                  0              0               1
# DE0 4 OCGT                  0              0               1
# DE0 4 coal                  0              0               1
# DE0 4 offwind-ac            0              0               1
# DE0 4 offwind-dc            0              0               1
# DE0 4 onwind                0              0               1
# DE0 4 solar                 0              0               1
#
#                   down_time_before  ramp_limit_up  ramp_limit_down  \
# name
# DE0 0 CCGT                       0            NaN              NaN
# DE0 0 OCGT                       0            NaN              NaN
# DE0 0 coal                       0            NaN              NaN
# DE0 0 onwind                     0            NaN              NaN
# DE0 0 solar                      0            NaN              NaN
# DE0 1 CCGT                       0            NaN              NaN
# DE0 1 OCGT                       0            NaN              NaN
# DE0 1 coal                       0            NaN              NaN
# DE0 1 onwind                     0            NaN              NaN
# DE0 1 solar                      0            NaN              NaN
# DE0 2 CCGT                       0            NaN              NaN
# DE0 2 OCGT                       0            NaN              NaN
# DE0 2 coal                       0            NaN              NaN
# DE0 2 offwind-ac                 0            NaN              NaN
# DE0 2 offwind-dc                 0            NaN              NaN
# DE0 2 onwind                     0            NaN              NaN
# DE0 2 solar                      0            NaN              NaN
# DE0 3 CCGT                       0            NaN              NaN
# DE0 3 OCGT                       0            NaN              NaN
# DE0 3 coal                       0            NaN              NaN
# DE0 3 onwind                     0            NaN              NaN
# DE0 3 solar                      0            NaN              NaN
# DE0 4 CCGT                       0            NaN              NaN
# DE0 4 OCGT                       0            NaN              NaN
# DE0 4 coal                       0            NaN              NaN
# DE0 4 offwind-ac                 0            NaN              NaN
# DE0 4 offwind-dc                 0            NaN              NaN
# DE0 4 onwind                     0            NaN              NaN
# DE0 4 solar                      0            NaN              NaN
#
#                   ramp_limit_start_up  ramp_limit_shut_down
# name
# DE0 0 CCGT                        1.0                   1.0
# DE0 0 OCGT                        1.0                   1.0
# DE0 0 coal                        1.0                   1.0
# DE0 0 onwind                      1.0                   1.0
# DE0 0 solar                       1.0                   1.0
# DE0 1 CCGT                        1.0                   1.0
# DE0 1 OCGT                        1.0                   1.0
# DE0 1 coal                        1.0                   1.0
# DE0 1 onwind                      1.0                   1.0
# DE0 1 solar                       1.0                   1.0
# DE0 2 CCGT                        1.0                   1.0
# DE0 2 OCGT                        1.0                   1.0
# DE0 2 coal                        1.0                   1.0
# DE0 2 offwind-ac                  1.0                   1.0
# DE0 2 offwind-dc                  1.0                   1.0
# DE0 2 onwind                      1.0                   1.0
# DE0 2 solar                       1.0                   1.0
# DE0 3 CCGT                        1.0                   1.0
# DE0 3 OCGT                        1.0                   1.0
# DE0 3 coal                        1.0                   1.0
# DE0 3 onwind                      1.0                   1.0
# DE0 3 solar                       1.0                   1.0
# DE0 4 CCGT                        1.0                   1.0
# DE0 4 OCGT                        1.0                   1.0
# DE0 4 coal                        1.0                   1.0
# DE0 4 offwind-ac                  1.0                   1.0
# DE0 4 offwind-dc                  1.0                   1.0
# DE0 4 onwind                      1.0                   1.0
# DE0 4 solar                       1.0                   1.0
#
# [29 rows x 29 columns]

# %%
#pd.DataFrame.from_dict(n.keys())

# %%
#(len(network_paths)+10)

# %% [markdown]
# ## Data preparation

# %% [markdown]
# ### Amount of unintended cycling

# %% [markdown]
# The following steps are described below to detect unintended storage cycling:
# 1. Reading efficiencies
# 2. Create charging and discharging timeseries
# 3. Calculate amount of aggregated unintended storage cycling [MWh]
# 4. Summary outputs

# %% [markdown]
# #### 1. Reading efficiencies

# %%
cd '/home/max/OneDrive/PHD-Flexibility/08_2_SecondPaper/unintended-storage-cycling'
# Out:
# /home/max/OneDrive/PHD-Flexibility/08_2_SecondPaper/unintended-storage-cycling

# %%
costs = pd.read_csv("pypsa-eur-test1/data/costs.csv")
costs.head()
# Out:
#       technology  year      parameter  value      unit  \
# 0  solar-rooftop  2030  discount rate   0.04  per unit
# 1         onwind  2030       lifetime  30.00     years
# 2        offwind  2030       lifetime  30.00     years
# 3          solar  2030       lifetime  25.00     years
# 4  solar-rooftop  2030       lifetime  25.00     years
#
#                                               source
# 0                             standard for decentral
# 1  DEA https://ens.dk/en/our-services/projections...
# 2  DEA https://ens.dk/en/our-services/projections...
# 3                                            IEA2010
# 4                                            IEA2010

# %%
##READING EFFICIENCY
costs = pd.read_csv("pypsa-eur-test1/data/costs.csv")
electrolysor_effi = costs.iloc[89]['value']
fuel_cell_effi = costs.iloc[93]['value']
battery_effi = costs.iloc[115]['value']

print(electrolysor_effi)
print(fuel_cell_effi)
print(battery_effi)
# Out:
# 0.8
# 0.58
# 0.9

# %% [markdown]
# ## 2. Functions. Create charging and Discharging Timeseries

# %% [markdown]
# Dataframe should look like:
# USC(y-xis).sum for battery and H2
# MC(x-axis)
#
# ##Y-Axis MAYBE SMT LIKE BELOW:
#
# Counting USC: print("USC/Discharge",(df['usc_h2'].mean()/df['p3_h2'].mean()))
#
#
# ##Generated indicators
# Artificial FLH Discharger = (df['p3_h2']/df['p3_h2'].max()).mean()*8760)
# True FLH Discharger = ((df['p3_h2_corr']/df['p3_h2_corr'].max()).mean()*8760)             # not sure if corr. works
# USC indicator as percentage over the year = (Artificial/True FLH)/8760
# USC indicator as percentage over the year = ((df['p0_b']-df['p0_b_corr'])/df['p0_b_corr'].max()).mean()
# USC indicator as timeseries = ((df['p0_h2']-df['p0_h2_corr'])/df['p0_h2_corr'].max())     # not sure if corr. works
# USC curtailment =  usc_b[col][row] or  usc_h2[col][row]
#
#
# #Note that ['usc_h2'] includes charging and discharging artififical curtailment.
# #example definition (p2_b[col][row] - p3_b[col][row]) + p2_b[col][row] / battery_effi

# %%
def create_p_df(n, name):
    
    ## CHARGING AND DISCHARGING TIMESERIES
        # p0 & p1 are related to charging
        # p2 & p3 are related to discharging
        # p0 * effi = p1

    ## Abbreviations
        #h2 = Hydrogen storage
        #b = battery storage

    ## REMOVES THE COLUMN INDEX (Code explanation)
        #.transpose().reset_index(drop = True, inplace = False).transpose()

    p0_h2 = abs(n.links_t.p0.filter(like='Electrolysis', axis='columns')).transpose().reset_index(drop = True, inplace = False).transpose()
    p1_h2 = abs(n.links_t.p1.filter(like='Electrolysis', axis='columns')).transpose().reset_index(drop = True, inplace = False).transpose()
    p2_h2 = abs(n.links_t.p0.filter(like='Fuel Cell', axis='columns')).transpose().reset_index(drop = True, inplace = False).transpose()
    p3_h2 = abs(n.links_t.p1.filter(like='Fuel Cell', axis='columns')).transpose().reset_index(drop = True, inplace = False).transpose()

#     p0_b = abs(n.links_t.p0.filter(like='battery charger', axis='columns')).transpose().reset_index(drop = True, inplace = False).transpose()
#     p1_b = abs(n.links_t.p1.filter(like='battery charger', axis='columns')).transpose().reset_index(drop = True, inplace = False).transpose()
#     p2_b = abs(n.links_t.p0.filter(like='battery discharger', axis='columns')).transpose().reset_index(drop = True, inplace = False).transpose()
#     p3_b = abs(n.links_t.p1.filter(like='battery discharger', axis='columns')).transpose().reset_index(drop = True, inplace = False).transpose()


    #Dataframes
    df = pd.DataFrame(data=(p0_h2.sum(axis=1)), columns=['p0_h2'])
    df['p1_h2'] = p1_h2.sum(axis=1)
    df['p2_h2'] = p2_h2.sum(axis=1)
    df['p3_h2'] = p3_h2.sum(axis=1)
#     df['p0_b'] = p0_b.sum(axis=1)
#     df['p1_b'] = p1_b.sum(axis=1)
#     df['p2_b'] = p2_b.sum(axis=1)
#     df['p3_b'] = p3_b.sum(axis=1)
    df['type'] = name
    return(df)

# %% [markdown]
# #### 3. Calculate amount of aggregated unintended storage cycling

# %%
def add_pcorr_and_usc_2_df(n, name):

    ## CHARGING AND DISCHARGING TIMESERIES
        # p0 & p1 are related to charging
        # p2 & p3 are related to discharging
        # p0 * effi = p1

    ## Abbreviations
        #h2 = Hydrogen storage
        #b = battery storage

    ## REMOVES THE COLUMN INDEX (Code explanation)
        #.transpose().reset_index(drop = True, inplace = False).transpose()

    p0_h2 = abs(n.links_t.p0.filter(like='Electrolysis', axis='columns')).transpose().reset_index(drop = True, inplace = False).transpose()
    p1_h2 = abs(n.links_t.p1.filter(like='Electrolysis', axis='columns')).transpose().reset_index(drop = True, inplace = False).transpose()
    p2_h2 = abs(n.links_t.p0.filter(like='Fuel Cell', axis='columns')).transpose().reset_index(drop = True, inplace = False).transpose()
    p3_h2 = abs(n.links_t.p1.filter(like='Fuel Cell', axis='columns')).transpose().reset_index(drop = True, inplace = False).transpose()

#     p0_b = abs(n.links_t.p0.filter(like='battery charger', axis='columns')).transpose().reset_index(drop = True, inplace = False).transpose()
#     p1_b = abs(n.links_t.p1.filter(like='battery charger', axis='columns')).transpose().reset_index(drop = True, inplace = False).transpose()
#     p2_b = abs(n.links_t.p0.filter(like='battery discharger', axis='columns')).transpose().reset_index(drop = True, inplace = False).transpose()
#     p3_b = abs(n.links_t.p1.filter(like='battery discharger', axis='columns')).transpose().reset_index(drop = True, inplace = False).transpose()

    #Dataframes
    df = pd.DataFrame(data=(p0_h2.sum(axis=1)), columns=['p0_h2'])
    df['p1_h2'] = p1_h2.sum(axis=1)
    df['p2_h2'] = p2_h2.sum(axis=1)
    df['p3_h2'] = p3_h2.sum(axis=1)
#     df['p0_b'] = p0_b.sum(axis=1)
#     df['p1_b'] = p1_b.sum(axis=1)
#     df['p2_b'] = p2_b.sum(axis=1)
#     df['p3_b'] = p3_b.sum(axis=1)
    
    ## CHARGING AND DISCHARGING TIMESERIES
        # usc_h2 = timeseries of unintended storage cycling for hydrogen storage for all buses
        # usc_b = timeseries of unintended storage cycling for battery storage for all busses

    ## Abbreviations
        #h2 = Hydrogen storage
        #b = battery storage

    ## Number of required iterations
    i = p0_h2.shape[1] # number of columns
    j = p0_h2.shape[0] # number of rows

    ## Create empty dataframe

    usc_h2 = pd.DataFrame(np.zeros((j, i))) #Artificial curtailment from USC in H2
    usc_b = pd.DataFrame(np.zeros((j, i))) #Artificial curtailment from USC in Battery
    p0_h2_corr = pd.DataFrame(np.zeros((j, i)))
    p1_h2_corr = pd.DataFrame(np.zeros((j, i)))
    p2_h2_corr = pd.DataFrame(np.zeros((j, i)))
    p3_h2_corr = pd.DataFrame(np.zeros((j, i)))
#     p0_b_corr = pd.DataFrame(np.zeros((j, i)))
#     p1_b_corr = pd.DataFrame(np.zeros((j, i)))
#     p2_b_corr = pd.DataFrame(np.zeros((j, i)))
#     p3_b_corr = pd.DataFrame(np.zeros((j, i)))

    #Charge and discharge should never happen at the same time, as it is equal to dissipating energy. 
    #Dissipating energy in an energy storage is too expensive since it reduces the lifetime of these relative expensive devices.
    #There are cheaper ways to dissipate energy such as curtailing VRE or using electric coils.

    #Having charge and discharge at the same time is a signal USC exists.
    for col in range(i):
        for row in range(j):
            if p1_h2[col][row] > p2_h2[col][row]: #Charge cycle
                usc_h2[col][row] = (p2_h2[col][row] - p3_h2[col][row]) + p2_h2[col][row] / electrolysor_effi
                p0_h2_corr[col][row] = p0_h2[col][row] - p2_h2[col][row] / electrolysor_effi
                p1_h2_corr[col][row] = p1_h2[col][row] - p2_h2[col][row]
                p2_h2_corr[col][row] = 0
                p3_h2_corr[col][row] = 0
            else: #Discharge cycle
                usc_h2[col][row] = (p0_h2[col][row] - p1_h2[col][row]) + p1_h2[col][row]*(1 - fuel_cell_effi) 
                p3_h2_corr[col][row] = p3_h2[col][row] - p1_h2[col][row] * fuel_cell_effi
                p2_h2_corr[col][row] = p2_h2[col][row] - p1_h2[col][row]
                p1_h2_corr[col][row] = 0
                p0_h2_corr[col][row] = 0
#             if p1_b[col][row] > p2_b[col][row]: #Charge cycle
#                 usc_b[col][row] = (p2_b[col][row] - p3_b[col][row]) + p2_b[col][row] / battery_effi
#                 p0_b_corr[col][row] = p0_b[col][row] - p2_b[col][row] / battery_effi
#                 p1_b_corr[col][row] = p1_b[col][row] - p2_b[col][row]
#                 p2_b_corr[col][row] = 0
#                 p3_b_corr[col][row] = 0
#             else: #Discharge cycle
#                 usc_b[col][row] = (p0_b[col][row] - p1_b[col][row]) + p1_b[col][row]*(1 - battery_effi)
#                 p3_b_corr[col][row] = p3_b[col][row] - p1_b[col][row] * battery_effi
#                 p2_b_corr[col][row] = p2_b[col][row] - p1_b[col][row]
#                 p1_b_corr[col][row] = 0
#                 p0_b_corr[col][row] = 0
    
    #corrected timeseries
    df['p0_h2_corr'] = p0_h2_corr.sum(axis=1).values
    df['p1_h2_corr'] = p1_h2_corr.sum(axis=1).values
    df['p2_h2_corr'] = p2_h2_corr.sum(axis=1).values
    df['p3_h2_corr'] = p3_h2_corr.sum(axis=1).values
#     df['p0_b_corr'] = p0_b_corr.sum(axis=1).values
#     df['p1_b_corr'] = p1_b_corr.sum(axis=1).values
#     df['p2_b_corr'] = p2_b_corr.sum(axis=1).values
#     df['p3_b_corr'] = p3_b_corr.sum(axis=1).values
    df['type'] = name+"corr"

    #USC curtailment (/Artificial curtailment). Shoulb be added to VRE curtailment or cheap dissipator
    df['usc_curtailment_h2_t'] = usc_h2.sum(axis=1).values
    #df['usc_curtailment_b_t'] = usc_b.sum(axis=1).values
    df['usc_indicator_p0_h2_t'] = ((df['p0_h2'].values-df['p0_h2_corr'])/df['p0_h2_corr'].max())
    df['usc_indicator_p3_h2_t'] = ((df['p3_h2'].values-df['p3_h2_corr'])/df['p3_h2_corr'].max())
    #df['usc_indicator_p0_b_t'] = ((df['p0_b'].values-df['p0_b_corr'])/df['p0_b_corr'].max())
    #df['usc_indicator_p3_b_t'] = ((df['p3_b'].values-df['p3_b_corr'])/df['p3_b_corr'].max())
    df_corr = df
    
    return(df_corr)

# %%
def calculate_FLH(df, storage, name):
    if storage == "h2":
        artificial_FLH_H2_discharger = (df['p3_h2']/df['p3_h2'].max()).mean()*8760
        true_FLH_H2_discharger = (df['p3_h2_corr']/df['p3_h2_corr'].max()).mean()*8760
        difference_FLH_H2_discharger = artificial_FLH_H2_discharger - true_FLH_H2_discharger
        return(name, artificial_FLH_H2_discharger, true_FLH_H2_discharger, difference_FLH_H2_discharger)
    
    if storage == "electrolysor":
        artificial_FLH_h2_charger = ((df['p0_h2']/df['p0_h2'].max()).mean()*8760)
        true_FLH_h2_charger = (df['p0_h2_corr']/df['p0_h2_corr'].max()).mean()*8760
        difference_FLH_h2_charger = artificial_FLH_h2_charger - true_FLH_h2_charger
        return(name, artificial_FLH_h2_charger, true_FLH_h2_charger, difference_FLH_h2_charger)
    else:
        print("choose for <storage> between 'h2' or 'battery' in calculate_FLH(df, storage)")

# %%
def calculate_objective(n, name):
    objective = n.objective/(10**9)
    return(name, objective)

# %% [markdown]
# ## Prepare Data for Artificial FLH plot

# %%
values = list(ns.values())
keys = list(ns.keys())
FLH_h2_discharger =  []
FLH_b =  []
FLH_h2_charger = []

for i in range(0, len(keys)):
     A = add_pcorr_and_usc_2_df(values[i], keys[i])
     B = calculate_FLH(A, "h2", keys[i])
     C = calculate_FLH(A, "electrolysor", keys[i])
     FLH_h2_discharger.append(B)
     FLH_h2_charger.append(C)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
n = list(ns.values())[0]

for c in n.iterate_components(list(n.components.keys())[2:]):
    print(c.name)
    
n.carriers
# Out:
# Bus
# Carrier
# GlobalConstraint
# Line
# LineType
# TransformerType
# Link
# Load
# Generator
# StorageUnit
# Store
#               color             nice_name  co2_emissions
# name
# onwind      #235ebc          Onshore Wind            0.0
# offwind-ac  #6895dd    Offshore Wind (AC)            0.0
# offwind-dc  #74c6f2    Offshore Wind (DC)            0.0
# solar       #f9d002                 Solar            0.0
# PHS         #08ad97  Pumped Hydro Storage            0.0
# hydro       #08ad97       Reservoir & Dam            0.0
# ror         #4adbc8          Run of River            0.0
# H2          #ea048a      Hydrogen Storage            0.0

# %%
df = n.generators_t.p #.groupby(['carrier']).sum()

df = df.rename(columns=lambda x: x[6:])

df.groupby(['name'], axis=1).sum()
# Out:
# name                  offwind-ac   offwind-dc        onwind         ror  \
# name
# 2013-01-01 00:00:00   154.730305  3853.725606  26217.077916  238.100502
# 2013-01-01 01:00:00   155.632421  3769.205095  26383.732877  238.228656
# 2013-01-01 02:00:00   156.164326  3543.791439  26662.178654  238.443993
# 2013-01-01 03:00:00   156.396187  3457.772056  26690.077912  239.031807
# 2013-01-01 04:00:00   154.232595  3067.118707  27259.228451  239.980130
# ...                          ...          ...           ...         ...
# 2013-12-31 19:00:00    93.489795  4166.297941  24406.375548  229.923697
# 2013-12-31 20:00:00    89.309099  4144.803962  23896.218071  228.411842
# 2013-12-31 21:00:00    85.721824  4177.191840  23717.139036  228.000652
# 2013-12-31 22:00:00   101.345119  4123.308869  24214.959375  228.341817
# 2013-12-31 23:00:00    97.815163  4137.954582  23853.043386  228.644775
#
# name                  solar    offwind-ac    offwind-dc        onwind  \
# name
# 2013-01-01 00:00:00     0.0   9384.816139  24284.442723  23633.573064
# 2013-01-01 01:00:00     0.0   9415.331625  20319.149601  24772.022483
# 2013-01-01 02:00:00     0.0   9453.474318  16517.187995  25370.619345
# 2013-01-01 03:00:00     0.0   9362.977079  17338.621692  24898.610878
# 2013-01-01 04:00:00     0.0   9327.892854  15671.662549  24448.452088
# ...                     ...           ...           ...           ...
# 2013-12-31 19:00:00     0.0  11609.430219  37204.957182  19945.007535
# 2013-12-31 20:00:00     0.0  11398.986098  36876.486692  19857.761958
# 2013-12-31 21:00:00     0.0  11376.104154  37229.444118  19662.632496
# 2013-12-31 22:00:00     0.0  11433.443542  37638.652342  17634.064449
# 2013-12-31 23:00:00     0.0  11456.943446  37972.513353  16906.721729
#
# name                         ror  solar
# name
# 2013-01-01 00:00:00  1013.377206    0.0
# 2013-01-01 01:00:00  1012.519848    0.0
# 2013-01-01 02:00:00  1013.730116    0.0
# 2013-01-01 03:00:00  1011.935346    0.0
# 2013-01-01 04:00:00  1014.012275    0.0
# ...                          ...    ...
# 2013-12-31 19:00:00  1066.099738    0.0
# 2013-12-31 20:00:00  1050.113434    0.0
# 2013-12-31 21:00:00  1051.619700    0.0
# 2013-12-31 22:00:00  1033.542121    0.0
# 2013-12-31 23:00:00  1032.731722    0.0
#
# [8760 rows x 10 columns]

# %%
n.generators_t.p.sum().groupby(n.generators.carrier).sum()
n.stores_t.p.p.sum().groupby().sum()
n.stores.carrier
n.storage_units.carrier
# Out:
# name
# DE0 0 PHS         PHS
# DE0 1 PHS         PHS
# DE0 11 PHS        PHS
# DE0 12 PHS        PHS
# DE0 12 hydro    hydro
# DE0 13 PHS        PHS
# DE0 14 PHS        PHS
# DE0 15 PHS        PHS
# DE0 2 PHS         PHS
# DE0 3 PHS         PHS
# DE0 4 PHS         PHS
# DE0 6 PHS         PHS
# DE0 6 hydro     hydro
# DE0 7 hydro     hydro
# Name: carrier, dtype: object

# %% [markdown]
# # SOS

# %%
df_FLH_h2_discharger = pd.DataFrame(
    FLH_h2_discharger, 
    columns = ['Network','Artificial FLH','Corrected FLH','Difference FLH'])

df_FLH_h2_discharger['scenario'] = [
    #charger
    0, 
    10**-5,
    10**-4,
    10**-3,
    10**-2,
    10**-1,
    10**0,
    10**1,
    10**2,
    10**3,
    
    #discharger
    0, 
    10**-5,
    10**-4,
    10**-3,
    10**-2,
    10**-1,
    10**0,
    10**1,
    10**2,
    10**3,
    
    #store
    0, 
    10**-5,
    10**-4,
    10**-3,
    10**-2,
    10**-1,
    10**0,
    10**1,
    10**2,
    10**3,
    
    #vre
    0, 
    10**-5,
    10**-4,
    10**-3,
    10**-2,
    10**-1,
    10**0,
    10**1,
    10**2,
    10**3,
    ]
#if difference is close to 0, indicate true FLH

#print(df_FLH_h2_discharger)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-0ab15791d78d> in <module>
#       3     columns = ['Network','Artificial FLH','Corrected FLH','Difference FLH'])
#       4
# ----> 5 df_FLH_h2_discharger['scenario'] = [
#       6     #charger
#       7     0,
#
# ~/anaconda3/envs/pypsa-eur/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# ~/anaconda3/envs/pypsa-eur/lib/python3.8/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3237         """
#    3238         self._ensure_valid_index(value)
# -> 3239         value = self._sanitize_column(key, value)
#    3240         NDFrame._set_item(self, key, value)
#    3241
#
# ~/anaconda3/envs/pypsa-eur/lib/python3.8/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3894
#    3895             # turn me into an ndarray
# -> 3896             value = sanitize_index(value, self.index)
#    3897             if not isinstance(value, (np.ndarray, Index)):
#    3898                 if isinstance(value, list) and len(value) > 0:
#
# ~/anaconda3/envs/pypsa-eur/lib/python3.8/site-packages/pandas/core/internals/construction.py in sanitize_index(data, index)
#     749     """
#     750     if len(data) != len(index):
# --> 751         raise ValueError(
#     752             "Length of values "
#     753             f"({len(data)}) "
#
# ValueError: Length of values (40) does not match length of index (3)

# %%
df_FLH_h2_charger = pd.DataFrame(
    FLH_h2_charger, 
    columns = ['Network','Artificial FLH','Corrected FLH','Difference FLH'])

df_FLH_h2_charger['scenario'] = [
    #charger
    0, 
    10**-5,
    10**-4,
    10**-3,
    10**-2,
    10**-1,
    10**0,
    10**1,
    10**2,
    10**3,
    
    #discharger
    0, 
    10**-5,
    10**-4,
    10**-3,
    10**-2,
    10**-1,
    10**0,
    10**1,
    10**2,
    10**3,
    
    #store
    0, 
    10**-5,
    10**-4,
    10**-3,
    10**-2,
    10**-1,
    10**0,
    10**1,
    10**2,
    10**3,
    
    #vre
    0, 
    10**-5,
    10**-4,
    10**-3,
    10**-2,
    10**-1,
    10**0,
    10**1,
    10**2,
    10**3,
    ]
#if difference is close to 0, indicate true FLH

#print(df_FLH_h2_discharger)

# %%
FLH_h2_discharger = df_FLH_h2_discharger.drop('Network',axis=1).set_index("scenario") #.index_column("scenario")

# %% [markdown]
# ## Prepare Dataframe for MC-plot

# %%
cd "/home/max/OneDrive/PHD-Flexibility/08_2_SecondPaper/unintended-storage-cycling/Model_scripts"

# %%
import sys, os
import yaml

with open("config.yaml", 'r') as stream:
    config = yaml.safe_load(stream)

# %%
#def aggregate_costs(n, flatten=False, opts=None, existing_only=False):
for key, n in ns.items():
    assign_carriers(n)
    
costs = pd.DataFrame({k: aggregate_costs(n) for k, n in ns.items()}).sort_index(axis=1)#.drop("load")
costs = costs.rename(index=config["plotting"]["nice_names"])
costs = costs/10**9 #Conversion to billions
#costs[:]

# %%
costs = costs.rename(index={
    'H2 electrolysis': 'Hydrogen Storage',
    'H2 storage': 'Hydrogen Storage',
    'H2 fuel cell': 'Hydrogen Storage',
    'hydro+PHS': 'Reservoir & Dam & Pump Hydro'
                            })
costs = costs.groupby(["carrier"]).sum()
costs = costs.reindex([
    "Hydrogen Storage",
    "Reservoir & Dam & Pump Hydro",
    "Run of River",
    "Offshore Wind (AC)",
    "Offshore Wind (DC)",
    "Onshore Wind",
    "Solar",
    "Transmission Lines"
])
#costs['colors']
costs

# %%
costs= costs.rename(columns={
    #charger
    "n10": 0, 
    "n11": 10**-5,
    "n12": 10**-4,
    "n13": 10**-3,
    "n14": 10**-2,
    "n15": 10**-1,
    "n16": 10**0,
    "n17": 10**1,
    "n18": 10**2,
    "n19": 10**3,
    
    #discharger
    "n20": 0, 
    "n21": 10**-5,
    "n22": 10**-4,
    "n23": 10**-3,
    "n24": 10**-2,
    "n25": 10**-1,
    "n26": 10**0,
    "n27": 10**1,
    "n28": 10**2,
    "n29": 10**3,
    
    #store
    "n30": 0, 
    "n31": 10**-5,
    "n32": 10**-4,
    "n33": 10**-3,
    "n34": 10**-2,
    "n35": 10**-1,
    "n36": 10**0,
    "n37": 10**1,
    "n38": 10**2,
    "n39": 10**3,
    
    #vre
    "n40": 0, 
    "n41": 10**-5,
    "n42": 10**-4,
    "n43": 10**-3,
    "n44": 10**-2,
    "n45": 10**-1,
    "n46": 10**0,
    "n47": 10**1,
    "n48": 10**2,
    "n49": 10**3,
})

# %% [markdown]
# ## Plot FLH _H2

# %%
##NOTES. 
#mc_discharger = n10-n19
#mc_ratio = n20-n29
#mc_vre = n30-n39

# %%
lines = FLH_h2_discharger.iloc[0:10,:].plot(style='.-')
plt.xscale("log")
plt.title("Adding Marginal Cost to Charger")
plt.xlabel("Marginal Cost Input Charger [€/MWh]")
plt.ylabel("Discharger Full Load Hours [h]") #(full usage/year)

# %%
lines = FLH_h2_discharger.iloc[10:20,:].plot(style='.-')
plt.xscale("log")
plt.title("Adding Marginal Cost to Discharger")
plt.xlabel("Marginal Cost Input Discharger [€/MWh]")
plt.ylabel("Discharger Full Load Hours [h]") #(full usage/year)

# %%
lines = FLH_h2_discharger.iloc[20:30,:].plot(style='.-')
plt.xscale("log")
plt.title("Adding Marginal Cost to H2-Tank")
plt.xlabel("Marginal Cost Input H2-Tank [€/MWh]")
plt.ylabel("Discharger Full Load Hours [h]") #(full usage/year)

# %%
lines = FLH_h2_discharger.iloc[30:40,:].plot(style='.-')
plt.xscale("log")
plt.title("Adding Marginal Cost to VRE")
plt.xlabel("Marginal Cost Input VRE [€/MWh]")
plt.ylabel("Discharger Full Load Hours [h]") #(full usage/year)

# %%
FLH_h2_discharger.iloc[0:10,:]
FLH_h2_discharger.iloc[10:20,:]
FLH_h2_discharger.iloc[20:30,:]
FLH_h2_discharger.iloc[30:40,:]

# %% [markdown]
# ## Plot Total System Cost

# %%
##NOTES. 
#mc_discharger = n10-n19
#mc_ratio = n20-n29
#mc_vre = n30-n39

# %%
color = ("#b8ea04", 
"#ea048a", 
'#08ad97', 
"#4adbc8", 
"#6895dd", 
"#74c6f2", 
"#235ebc", 
"#f9d002", 
"#70af1d")

#battery,
#hydrogen storage
#reservoir & co
#run of river
#offshore AC
#offshore DC
#onshore
#solar
#transmission

# %%
costs.iloc[:,0:9].T.plot.bar(stacked=True, figsize=(10,10), color = color)
plt.legend(loc=(1.04,0))
plt.title("Adding Marginal Cost to Charger")
plt.xlabel("Marginal Cost Input Charger [€/MWh]")
plt.ylabel("Total System Costs [B€ p.a.]")

# %%
costs.iloc[:,10:19].T.plot.bar(stacked=True, figsize=(10,10),color = color)
plt.legend(loc=(1.04,0))
plt.title("Adding Marginal Cost to Discharger")
plt.xlabel("Marginal Cost Input Discharger [€/MWh]")
plt.ylabel("Total System Costs [B€ p.a.]")

# %%
costs.iloc[:,20:29].T.plot.bar(stacked=True, figsize=(10,10),color = color)
plt.legend(loc=(1.04,0))
plt.title("Adding Marginal Cost to H2-tank")
plt.xlabel("Marginal Cost Input to H2-tank [€/MWh]")
plt.ylabel("Total System Costs [B€ p.a.]")

# %%
costs.iloc[:,30:39].T.plot.bar(stacked=True, figsize=(10,10),color = color)
plt.legend(loc=(1.04,0))
plt.title("Adding Marginal Cost to VRE")
plt.xlabel("Marginal Cost Input to VRE [€/MWh]")
plt.ylabel("Total System Costs [B€ p.a.]")

# %%
###CHECK
values = list(ns.values())
keys = list(ns.keys())
objective =  []

for i in range(0, len(keys)):
    C = calculate_objective(values[i], keys[i])
    objective.append(C)

# %%
objective

# %% [markdown]
# # FLH/capacity factor generator

# %%
cd "/home/max/OneDrive/PHD-Flexibility/08_2_SecondPaper/unintended-storage-cycling/Model_scripts"

# %%
import sys, os
import yaml

with open("config.yaml", 'r') as stream:
    config = yaml.safe_load(stream)

# %%
def aggregate_p(n):
    return pd.concat([
        n.generators_t.p.sum().groupby(n.generators.carrier).sum(),
        n.storage_units_t.p.sum().groupby(n.storage_units.carrier).sum(),
        n.stores_t.p.sum().groupby(n.stores.carrier).sum(),
        n.links.groupby("carrier").p_nom_opt.sum(),
        -n.loads_t.p.sum().groupby(n.loads.carrier).sum()
        ])

# %%
#def aggregate_costs(n, flatten=False, opts=None, existing_only=False):
for key, n in ns.items():
    assign_carriers(n)
    
costs = pd.DataFrame({k: aggregate_p_curtailed(n)/(aggregate_p_nom(n)*8760) for k, n in ns.items()}).sort_index(axis=1)#.drop("load")
#colors = costs.index.map(config["plotting"]["tech_colors"])
#colors = (config["plotting"]["tech_colors"])
costs = costs.rename(index=config["plotting"]["nice_names"])

costs = costs #Conversion to billions
#costs[:]

# %%
#costs
#Percentage of curtailment

# %%
((
    costs.loc["Solar"]
    +costs.loc["Onshore Wind"]
    +costs.loc["Offshore Wind (AC)"]
    +costs.loc["Offshore Wind (DC)"]
    +costs.loc["Run of River"]
    #costs.loc["hydro+PHS"]
    
)/5).plot(style='.-')

plt.title("Percentage of Curtailment")
plt.xlabel("Charger - Discharger - Storage tank - VRE")
plt.ylabel("Average VRE p_curtailed/p_nom")

# %%
#def aggregate_costs(n, flatten=False, opts=None, existing_only=False):
for key, n in ns.items():
    assign_carriers(n)
    
costs = pd.DataFrame({k: aggregate_p(n)/(aggregate_p_nom(n)*8760) for k, n in ns.items()}).sort_index(axis=1)#.drop("load")
#colors = costs.index.map(config["plotting"]["tech_colors"])
#colors = (config["plotting"]["tech_colors"])
costs = costs.rename(index=config["plotting"]["nice_names"])

costs = costs #Conversion to billions
#costs[:]

# %%
((
    costs.loc["Solar"]
    +costs.loc["Onshore Wind"]
    +costs.loc["Offshore Wind (AC)"]
    +costs.loc["Offshore Wind (DC)"]
    +costs.loc["Run of River"]
    #costs.loc["hydro+PHS"]
    
)/5).plot(style='.-')

plt.title("Capacity Factor of VRE assets")
plt.xlabel("Charger - Discharger - Storage tank - VRE")
plt.ylabel("p/(p_nom*8760)")

# %%
#def aggregate_costs(n, flatten=False, opts=None, existing_only=False):
for key, n in ns.items():
    assign_carriers(n)
    
costs = pd.DataFrame({k: aggregate_p(n)/(aggregate_p_nom(n)) for k, n in ns.items()}).sort_index(axis=1)#.drop("load")
#colors = costs.index.map(config["plotting"]["tech_colors"])
#colors = (config["plotting"]["tech_colors"])
costs = costs.rename(index=config["plotting"]["nice_names"])

costs = costs #Conversion to billions
#costs[:]

# %%
costs
#FLH of generators

# %%
((
    costs.loc["Solar"]
    +costs.loc["Onshore Wind"]
    +costs.loc["Offshore Wind (AC)"]
    +costs.loc["Offshore Wind (DC)"]
    +costs.loc["Run of River"]
    #+costs.loc["hydro+PHS"]
    
)/5).plot(style='.-')

plt.title("VRE Full Load Hour")
plt.xlabel("Charger - Discharger - Storage tank - VRE")
plt.ylabel("Average p/pnom [h]")

# %%
#def aggregate_costs(n, flatten=False, opts=None, existing_only=False):
for key, n in ns.items():
    assign_carriers(n)
    
costs = pd.DataFrame({k: aggregate_p_nom(n) for k, n in ns.items()}).sort_index(axis=1)#.drop("load")
#colors = costs.index.map(config["plotting"]["tech_colors"])
#colors = (config["plotting"]["tech_colors"])
costs = costs.rename(index=config["plotting"]["nice_names"])

costs = costs #Conversion to billions
#costs[:]

# %%
#optimised capacity
costs

# %%
((
    costs.loc["Solar"]
    +costs.loc["Onshore Wind"]
    +costs.loc["Offshore Wind (AC)"]
    +costs.loc["Offshore Wind (DC)"]
    +costs.loc["Run of River"]
    #+costs.loc["hydro+PHS"]
    
)/5).plot(style='.-')

plt.title("Total Installed Power")
plt.xlabel("Charger - Discharger - Storage tank - VRE")
plt.ylabel("p_nom in [MW]")

# %%
#def aggregate_costs(n, flatten=False, opts=None, existing_only=False):
for key, n in ns.items():
    assign_carriers(n)
    
costs = pd.DataFrame({k: aggregate_p(n) for k, n in ns.items()}).sort_index(axis=1)#.drop("load")
#colors = costs.index.map(config["plotting"]["tech_colors"])
#colors = (config["plotting"]["tech_colors"])
costs = costs.rename(index=config["plotting"]["nice_names"])

costs = costs #Conversion to billions
#costs[:]

# %%
#power output
costs

# %%
((
    costs.loc["Solar"]
    +costs.loc["Onshore Wind"]
    +costs.loc["Offshore Wind (AC)"]
    +costs.loc["Offshore Wind (DC)"]
    +costs.loc["Run of River"]
    +costs.loc["hydro+PHS"]
    
)/6).plot(style='.-')

plt.title("Aggregated power output")
plt.xlabel("Charger - Discharger - Storage tank - VRE")
plt.ylabel("p in [MW]")
